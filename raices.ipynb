# %%
import numpy as np
from scipy.optimize import newton, bisect


def f(x):
    return x**5 + 5.25*x**4 + 4.125*x**3 - 9.125*x**2 - 14.625*x - 5.625

def df(x):
    return 5*x**4 + 21*x**3 + 12.375*x**2 - 18.25*x - 14.625


coefs = [1, 5.25, 4.125, -9.125, -14.625, -5.625]
all_roots = np.roots(coefs)
real_roots = np.real_if_close(all_roots, tol=1e-5)
unique_roots = np.unique(np.round(real_roots, 5))

sorted_roots = np.sort(unique_roots)

print("Raíces únicas ordenadas:", sorted_roots)
# Out:
# Raíces únicas ordenadas: [-3.75 -1.    1.5 ]
